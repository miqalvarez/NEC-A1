# %% [markdown]
# # Medical_insurance.csv

# %% [markdown]
# ### Read data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the data
df = pd.read_csv('Medical_insurance.csv')
# Print the first 5 rows
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ### Preprocess

# %%
# Check for missing values
df.isna().sum()

# Delete the rows with missing values
df = df.dropna()

# Turn the categorical variables into 0 and 1 
df = pd.get_dummies(df, drop_first=True)

# Convert boolean values to 0 and 1
df['smoker_yes'] = df['smoker_yes'].astype(int)
df['sex_male'] = df['sex_male'].astype(int)
df['region_northwest'] = df['region_northwest'].astype(int)
df['region_southeast'] = df['region_southeast'].astype(int)
df['region_southwest'] = df['region_southwest'].astype(int)
df_og = df.copy()

# Move the charges column to the end
charges = df.pop('charges')
df['charges'] = charges

print(df.shape)
# Remove the outliers
df = df[df['bmi'] < 50]
df = df[df['charges'] < 50000]
print(df.shape)

# Print the first 5 rows
df.head()
# Out:
# (2772, 9)
# (2752, 9)
#    age     bmi  children  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0         0           1                 0
# 1   18  33.770         1         1           0                 0
# 2   28  33.000         3         1           0                 0
# 3   33  22.705         0         1           0                 1
# 4   32  28.880         0         1           0                 1
#
#    region_southeast  region_southwest      charges
# 0                 0                 1  16884.92400
# 1                 1                 0   1725.55230
# 2                 1                 0   4449.46200
# 3                 0                 0  21984.47061
# 4                 0                 0   3866.85520

# %% [markdown]
# ### Normalize data

# %%
# Normalize the data to 0 - 1 of the first 8 columns
for column in df.columns[0:8]:
    df[column] = df[column] / df[column].max()

# Scale the charges column to 0.1 - 0.9
df['charges'] = df['charges'] / df['charges'].max() * 0.8 + 0.1

# Print the first 5 rows
df.head()
# Out:
#         age       bmi  children  sex_male  smoker_yes  region_northwest  \
# 0  0.296875  0.568691       0.0       0.0         1.0               0.0
# 1  0.281250  0.688341       0.2       1.0         0.0               0.0
# 2  0.437500  0.672646       0.6       1.0         0.0               0.0
# 3  0.515625  0.462801       0.0       1.0         0.0               1.0
# 4  0.500000  0.588667       0.0       1.0         0.0               1.0
#
#    region_southeast  region_southwest   charges
# 0               0.0               1.0  0.372460
# 1               1.0               0.0  0.127844
# 2               1.0               0.0  0.171798
# 3               0.0               0.0  0.454748
# 4               0.0               0.0  0.162397

# %%
# Output the data to a CSV file
df.to_csv('Medical-insurance-normalized.csv', index=False)

# %%
# Unscale data
df['charges'] = (df['charges'] - 0.1) / 0.8 * df_og['charges'].max()

# Unnormalize data
for column in df.columns[0:8]:
    df[column] = df[column] * df_og[column].max()

# Print the first 5 rows
df.head()
# Out:
#     age        bmi  children  sex_male  smoker_yes  region_northwest  \
# 0  19.0  30.214574       0.0       0.0         1.0               0.0
# 1  18.0  36.571547       1.0       1.0         0.0               0.0
# 2  28.0  35.737668       3.0       1.0         0.0               0.0
# 3  33.0  24.588599       0.0       1.0         0.0               1.0
# 4  32.0  31.275874       0.0       1.0         0.0               1.0
#
#    region_southeast  region_southwest       charges
# 0               0.0               1.0  21718.628476
# 1               1.0               0.0   2219.532011
# 2               1.0               0.0   5723.224582
# 3               0.0               0.0  28278.039595
# 4               0.0               0.0   4973.832957
